# %% [markdown]
# # DQN

# %%
! python3 single_agent_training.py
# Out:
# /Users/Marvin/opt/miniconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Training 1 agents on 35x35	 Episode 0	 Average Score: -0.517	Dones: 0.00%	Epsilon: 1.00 	 Action Probabilities: 	 [0.21428571 0.17857143 0.21428571 0.28571429 0.10714286]
# Training 1 agents on 35x35	 Episode 100	 Average Score: -0.784	Dones: 10.00%	Epsilon: 0.74 	 Action Probabilities: 	 [0.08196721 0.13114754 0.42622951 0.13114754 0.2295082 ]
# Training 1 agents on 35x35	 Episode 200	 Average Score: -0.587	Dones: 5.00%	Epsilon: 0.55 	 Action Probabilities: 	 [0.10714286 0.10714286 0.10714286 0.07142857 0.60714286]
# Training 1 agents on 35x35	 Episode 300	 Average Score: -0.599	Dones: 10.00%	Epsilon: 0.40 	 Action Probabilities: 	 [0.22727273 0.04545455 0.         0.04545455 0.68181818]
# ...

# %%
from single_agent_training import *

# parser = ArgumentParser()
# parser.add_argument("-n", "--n_episodes", dest="n_episodes", help="number of episodes to run", default=500, type=int)
# args = parser.parse_args()

train_agent(500)
# Out:
# /Users/Marvin/opt/miniconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Training 1 agents on 35x35	 Episode 0	 Average Score: 0.000	Dones: 100.00%	Epsilon: 1.00 	 Action Probabilities: 	 [0.17391304 0.2173913  0.32608696 0.15217391 0.13043478]
# Training 1 agents on 35x35	 Episode 100	 Average Score: -0.787	Dones: 23.00%	Epsilon: 0.74 	 Action Probabilities: 	 [0.30232558 0.13953488 0.18604651 0.11627907 0.25581395]
# Training 1 agents on 35x35	 Episode 200	 Average Score: -0.683	Dones: 27.00%	Epsilon: 0.55 	 Action Probabilities: 	 [0.18181818 0.51515152 0.18181818 0.09090909 0.03030303]
# Training 1 agents on 35x35	 Episode 300	 Average Score: -0.859	Dones: 16.00%	Epsilon: 0.40 	 Action Probabilities: 	 [0.10714286 0.39285714 0.14285714 0.25       0.10714286]
# ...

# %%
! python3 multi_agent_training.py
# Out:
# Install wandb to log to Weights & Biases
# Namespace(n_episodes=2500, training_env_config=0, evaluation_env_config=0, n_evaluation_episodes=25, checkpoint_interval=100, eps_start=1.0, eps_end=0.01, eps_decay=0.99, buffer_size=100000, buffer_min_size=0, restore_replay_buffer='', save_replay_buffer=False, batch_size=128, gamma=0.99, tau=0.001, learning_rate=5e-05, hidden_size=128, update_every=8, use_gpu=False, num_threads=1, render=False)
# <class 'argparse.Namespace'>
#
# Training parameters:
# {'batch_size': 128,
#  'buffer_min_size': 0,
#  'buffer_size': 100000,
#  'checkpoint_interval': 100,
#  'eps_decay': 0.99,
#  'eps_end': 0.01,
#  'eps_start': 1.0,
#  'evaluation_env_config': 0,
#  'gamma': 0.99,
#  'hidden_size': 128,
#  'learning_rate': 5e-05,
#  'n_episodes': 2500,
#  'n_evaluation_episodes': 25,
#  'num_threads': 1,
#  'render': False,
#  'restore_replay_buffer': '',
#  'save_replay_buffer': False,
#  'tau': 0.001,
#  'training_env_config': 0,
#  'update_every': 8,
# ...

# %% [markdown]
# # PPO

# %%
! python3 multi_agent_training.py
# Out:
# Install wandb to log to Weights & Biases
# Namespace(n_episodes=2500, training_env_config=0, evaluation_env_config=0, n_evaluation_episodes=25, checkpoint_interval=100, eps_start=1.0, eps_end=0.01, eps_decay=0.99, buffer_size=100000, buffer_min_size=0, restore_replay_buffer='', save_replay_buffer=False, batch_size=128, gamma=0.99, tau=0.001, learning_rate=5e-05, hidden_size=128, update_every=8, use_gpu=False, num_threads=1, render=False)
# <class 'int'>
#
# Training parameters:
# {'batch_size': 128,
#  'buffer_min_size': 0,
#  'buffer_size': 100000,
#  'checkpoint_interval': 100,
#  'eps_decay': 0.99,
#  'eps_end': 0.01,
#  'eps_start': 1.0,
#  'evaluation_env_config': 0,
#  'gamma': 0.99,
#  'hidden_size': 128,
#  'learning_rate': 5e-05,
#  'n_episodes': 2500,
#  'n_evaluation_episodes': 25,
#  'num_threads': 1,
#  'render': False,
#  'restore_replay_buffer': '',
#  'save_replay_buffer': False,
#  'tau': 0.001,
#  'training_env_config': 0,
#  'update_every': 8,
#  'use_gpu': False}
# ...

# %% [markdown]
# # PPO gamma = 0.5, lr = 0.1

# %%
! python3 multi_agent_training.py --gamma 0.5 --learning_rate 0.1
# Out:
# Install wandb to log to Weights & Biases
# Namespace(n_episodes=2500, training_env_config=0, evaluation_env_config=0, n_evaluation_episodes=25, checkpoint_interval=100, eps_start=1.0, eps_end=0.01, eps_decay=0.99, buffer_size=100000, buffer_min_size=0, restore_replay_buffer='', save_replay_buffer=False, batch_size=128, gamma=0.5, tau=0.001, learning_rate=0.1, hidden_size=128, update_every=8, use_gpu=False, num_threads=1, render=False)
# <class 'int'>
#
# Training parameters:
# {'batch_size': 128,
#  'buffer_min_size': 0,
#  'buffer_size': 100000,
#  'checkpoint_interval': 100,
#  'eps_decay': 0.99,
#  'eps_end': 0.01,
#  'eps_start': 1.0,
#  'evaluation_env_config': 0,
#  'gamma': 0.5,
#  'hidden_size': 128,
#  'learning_rate': 0.1,
#  'n_episodes': 2500,
#  'n_evaluation_episodes': 25,
#  'num_threads': 1,
#  'render': False,
#  'restore_replay_buffer': '',
#  'save_replay_buffer': False,
#  'tau': 0.001,
#  'training_env_config': 0,
#  'update_every': 8,
#  'use_gpu': False}
#
# ...

# %% [markdown]
# # PPO --gamma 0.99 --learning_rate 0.2

# %%
! python3 multi_agent_training.py --gamma 0.99 --learning_rate 0.2
# Out:
# Install wandb to log to Weights & Biases
# Namespace(n_episodes=2500, training_env_config=0, evaluation_env_config=0, n_evaluation_episodes=25, checkpoint_interval=100, eps_start=1.0, eps_end=0.01, eps_decay=0.99, buffer_size=100000, buffer_min_size=0, restore_replay_buffer='', save_replay_buffer=False, batch_size=128, gamma=0.99, tau=0.001, learning_rate=0.2, hidden_size=128, update_every=8, use_gpu=False, num_threads=1, render=False)
# <class 'int'>
#
# Training parameters:
# {'batch_size': 128,
#  'buffer_min_size': 0,
#  'buffer_size': 100000,
#  'checkpoint_interval': 100,
#  'eps_decay': 0.99,
#  'eps_end': 0.01,
#  'eps_start': 1.0,
#  'evaluation_env_config': 0,
#  'gamma': 0.99,
#  'hidden_size': 128,
#  'learning_rate': 0.2,
#  'n_episodes': 2500,
#  'n_evaluation_episodes': 25,
#  'num_threads': 1,
#  'render': False,
#  'restore_replay_buffer': '',
#  'save_replay_buffer': False,
#  'tau': 0.001,
#  'training_env_config': 0,
#  'update_every': 8,
#  'use_gpu': False}
#
# ...
